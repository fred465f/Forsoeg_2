# %%
# Standard Libraries
from Lab import *

# %%
lab = Lab()
# Out:
#         Imported packages and functions:
#         -----------------------------------------
#         Imported matplotlib.pyplot as plt
#         and imported numpy as np
#         and imported pandas as pd
#         and imported numpy.fft as fft
#         and imported seaborn as sns
#         and imported time
#         and imported curve_fit from scipy.optimize

# %%
# Functions
def find_max(x, y):
    # First max
    maks_y = max(y)
    maks_index = y.index(maks_y)
    maks_x = x[maks_index]
    return maks_x, maks_y, maks_index

def find_min(x, y):
    # First min
    min_y = min(y)
    min_index = y.index(min_y)
    min_x = x[min_index]
    return min_x, min_y, min_index

def find_ekstremums_punkter(x, y, period):
    min_x, min_y, min_index = find_min(x, y)
    maks_x, maks_y, maks_index = find_maks(x, y)
    
    # Num periods
    num_periods = int(x[-1] - x[0] // period)
    
    # Find mins
    mins = []
    if min_x < period:
        for i in range(1, num_periods):
            mins.append(min_x * num_periods * i)
    else:
        min_x_new = min_x
        count = 0
        while min_x_new > period and count <= 100:
            min_x_new -= period
            count += 1
        for i in range(1, num_periods):
            mins.append(min_x * num_periods * i)

# %%
# Generate test data - REMOVE before use!!!
omega = 10
frequency = 10 / (2 * np.pi)
data_x = np.linspace(0,10,10000)
data_y = [np.sin(omega * x) for x in data_x]
df_sin = pd.DataFrame({'x': data_x, 'sin': data_y})
df_sin.to_csv('../Data/sin_freq_10_test.csv')
print(frequency)
# Out:
# 1.5915494309189535

# %%
# Load csv fra en ydre mappe '..' går en mappe tilbage og '/Data' går ind i den ydre mappe Data
df_sin_imp = pd.read_csv('../Data/sin_test.csv')

# %%
# Add data (Only used to find frequency)
lab.add_experiment(name = 'sine', data = df_sin_imp)

# %%
# Make analysis (Only used to find frequency)
freq = lab.analysis(name = 'sine', analysis_type = 'Frequency', columns = [['x', 'sin']])
# Out:
#                                  ---- Frequency analysis ----
#
#
# Scatter-plot of data columns (x vs. sin) from experiment named "sine":
# Frequency of data from experiment named "sine":
# Frequencies found for columns x and sin from experiment named "sine" given current tolerance, 0.5:  [ 1.6 -1.6]
# Given the above results, the avg frequency was found to be:  1.6

# %%
# Data
sin = list(df_sin_imp['sin'])
xs = list(df_sin_imp['x'])

# First max
maks_sin_first = max(list(df_sin_imp['sin']))
maks_index_first = list(df_sin_imp['sin']).index(maks_sin_first)
maks_x_first = list(df_sin_imp['x'])[maks_index_first]

# First min
min_sin_first = min(list(df_sin_imp['sin']))
min_index_first = list(df_sin_imp['sin']).index(min_sin_first)
min_x_first = list(df_sin_imp['x'])[min_index_first]

# %%
# Plot first max and min
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.scatter(xs, sin, color = 'blue')
ax.scatter(maks_x_first, maks_sin_first, color = 'red')
ax.scatter(min_x_first, min_sin_first, color = 'green')

# %%
# All maxs
x_range = xs[-1] - xs[0]
period = 1/freq
'''
def find_xs(x, maks, period, xs):
    new_x = x + period
    if new_x >= maks:
        return x
    xs.append(new_x)
    return find_xs(new_x, maks, period, xs)
'''
number_of_period = int(x_range // period)
x_makss = [maks_x_first + period * i for i in range(number_of_period)]
sin_makss = [maks_sin_first] * number_of_period

# %%
# Plot first max
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
ax.scatter(xs, sin, color = 'blue')
ax.scatter(x_makss, sin_makss, color = 'red')

# %%
# Visualiser dataframe
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7a72636c91a4> in <module>
#       1 # Visualiser dataframe
# ----> 2 df.head()
#
# NameError: name 'df' is not defined

# %%
# Upload csv til en ydre mappe via. samme metode som for loading
df.to_csv('../Cleaned_Data/cleaned_test.csv')
